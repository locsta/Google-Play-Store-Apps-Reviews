# %% [markdown]
# ## Google Play Store apps and reviews

# %%
# Read in dataset
import pandas as pd

# contains all the details of the applications on Google Play. There are 13 features that describe a given app.
apps_with_duplicates = pd.read_csv("datasets/apps.csv")

# Drop duplicates from apps_with_duplicates
apps = apps_with_duplicates.drop_duplicates()

# %%
# Print a summary of apps dataframe
print(apps.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9659 entries, 0 to 9658
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      9659 non-null   int64
#  1   App             9659 non-null   object
#  2   Category        9659 non-null   object
#  3   Rating          8196 non-null   float64
#  4   Reviews         9659 non-null   int64
#  5   Size            8432 non-null   float64
#  6   Installs        9659 non-null   object
#  7   Type            9659 non-null   object
#  8   Price           9659 non-null   object
#  9   Content Rating  9659 non-null   object
#  10  Genres          9659 non-null   object
#  11  Last Updated    9659 non-null   object
#  12  Current Ver     9651 non-null   object
#  13  Android Ver     9657 non-null   object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 1.1+ MB
# None

# %%
# Have a look at a random sample of 5 rows
apps.sample(n=5)
# Out:
#       Unnamed: 0                                          App  \
# 9005       10166                         FA Player Essentials
# 1634        2087                           Pinkalicious Party
# 8826        9983      Survival Forest : Survivor Home Builder
# 1622        2075                Toddler Kids Puzzles PUZZINGO
# 2654        3383  Cute wallpapers & kawaii backgrounds images
#
#              Category  Rating  Reviews  Size    Installs  Type  Price  \
# 9005           SPORTS     5.0        7  68.0        100+  Free      0
# 1634           FAMILY     3.0        2  82.0        500+  Paid  $2.99
# 8826           FAMILY     3.6     9389  64.0  1,000,000+  Free      0
# 1622           FAMILY     4.6    14014  60.0  1,000,000+  Free      0
# 2654  PERSONALIZATION     4.6     4724   5.4  1,000,000+  Free      0
#
#      Content Rating                  Genres   Last Updated Current Ver  \
# 9005       Everyone                  Sports  July 23, 2018       1.6.0
# 1634       Everyone  Educational;Creativity  June 25, 2018       1.5.0
# 8826           Teen              Simulation   May 31, 2018       1.3.4
# 1622       Everyone     Education;Education   July 6, 2018        7.32
# 2654       Everyone         Personalization  July 30, 2018         1.2
#
#        Android Ver
# 9005  4.0.3 and up
# 1634    4.1 and up
# 8826    4.0 and up
# 1622  4.0.3 and up
# 2654  4.0.3 and up

# %%
# List of characters to remove
chars_to_remove = ["+", ",", "$"]
# List of column names to clean
cols_to_clean = ["Installs", "Price"]

# Loop for each column in cols_to_clean
for col in cols_to_clean:
    # Loop for each char in chars_to_remove
    for char in chars_to_remove:
        # Replace the character with an empty string
        apps[col] = apps[col].apply(lambda x: x.replace(char, ''))
    # Convert col to float data type
    apps[col] = apps[col].astype(float)
